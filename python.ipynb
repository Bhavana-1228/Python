# %%
a = int(input())
if a % 10 == 5:
    print(5)
else:
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = int(input())
#       2 if a % 10 == 5:
#       3     print(5)
#       4 else:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
day = int(input("Enter a number (1-7): "))

days = {
    1: "Monday",
    2: "Tuesday",
    3: "Wednesday",
    4: "Thursday",
    5: "Friday",
    6: "Saturday",
    7: "Sunday"
}

print(days.get(day, "Invalid day"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 day = int(input("Enter a number (1-7): "))
#       2
#       3 days = {
#       4     1: "Monday",
#
# ValueError: invalid literal for int() with base 10: ''
